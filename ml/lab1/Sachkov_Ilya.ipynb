# %% [markdown]
# <h1 align="center">📝 Homework: Markdown syntax in Juypter Notebook</h1>

# %% [markdown]
# ---

# %% [markdown]
# ## Task 1: Create Normal Headings (5 marks)

# %% [markdown]
# # My Title
# ## My Subtitle
# ### My Section

# %% [markdown]
# ---

# %% [markdown]
# ## Task 2: Center a Heading (10 marks)

# %% [markdown]
# <h1 align="center">Welcome to My Notebook</h1>

# %% [markdown]
# ---

# %% [markdown]
# ## Task 3: Insert an Image (10 marks)

# %% [markdown]
# ![img](https://i.ytimg.com/vi/SQJrYw1QvSQ/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBY9A7Gomuj6iHkoDkSidTzx0bZAw)

# %% [markdown]
# ---

# %% [markdown]
# ## Task 4: Resize an Image (10 marks)

# %% [markdown]
# <img width="200px" src="https://i.ytimg.com/vi/SQJrYw1QvSQ/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBY9A7Gomuj6iHkoDkSidTzx0bZAw">

# %% [markdown]
# ---

# %% [markdown]
# ## Task 5: Image + Text Side by Side (15 marks)

# %% [markdown]
# <table>
#     <tr>
#         <td><img width="200px" src="https://i.ytimg.com/vi/SQJrYw1QvSQ/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBY9A7Gomuj6iHkoDkSidTzx0bZAw"></td>
#         <td><- cute cat c:</td>
#     </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## Task 6: Display 3 Images Side by Side (15 marks)

# %% [markdown]
# <table>
#     <tr>
#         <td><img width="200px" src="https://i.ytimg.com/vi/SQJrYw1QvSQ/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBY9A7Gomuj6iHkoDkSidTzx0bZAw"></td>
#         <td><img width="200px" src="https://preview.redd.it/post-the-best-cat-memes-you-got-in-the-comments-please-v0-kg82lbnu0ste1.png?auto=webp&s=e6f9eee86484f5de3f4e31f3c33b2d07fb982bd5"></td>
#         <td><img width="200px" src="https://www.meowbox.com/cdn/shop/articles/Screen_Shot_2024-03-15_at_10.53.41_AM.png?v=1710525250"></td>
#     </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## Challenging Task: Centered Title with an Image (10 marks)

# %% [markdown]
# <h1 align="center">My Favorite Animal</h1>
# <div style="text-align: center;">
#   <img
#     src="https://i.pinimg.com/736x/ab/31/1a/ab311ad11ad973d24c7a94fdf5d59014.jpg"
#     style="display: inline-block; width: 50%;"
#   >
# </div>
